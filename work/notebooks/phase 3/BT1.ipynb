# %%
pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in /opt/conda/lib/python3.11/site-packages (1.0.1)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /opt/conda/lib/python3.11/site-packages (from kagglehub) (0.1.27)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from kagglehub) (23.2)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.11/site-packages (from kagglehub) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from kagglehub) (2.31.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from kagglehub) (4.66.1)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.11/site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (4.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->kagglehub) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/__init__.py:4
#       1 __version__ = "1.0.1"
#       3 import kagglehub.logger  # configures the library logger.
# ----> 4 from kagglehub import colab_cache_resolver, http_resolver, kaggle_cache_resolver, registry
#       5 from kagglehub.auth import login, whoami
#       6 from kagglehub.competition import competition_download
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/colab_cache_resolver.py:5
#       2 import os
#       3 import time
# ----> 5 from kagglehub.clients import ColabClient
#       6 from kagglehub.config import is_colab_cache_disabled
#       7 from kagglehub.exceptions import BackendError, NotFoundError
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/clients.py:22
#      19 from tqdm import tqdm
#      21 import kagglehub
# ---> 22 from kagglehub.cache import delete_from_cache, get_cached_archive_path
#      23 from kagglehub.config import get_kaggle_credentials
#      24 from kagglehub.datasets_enums import KaggleDatasetAdapter
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/cache.py:6
#       3 from pathlib import Path
#       5 from kagglehub.config import get_cache_folder
# ----> 6 from kagglehub.handle import CompetitionHandle, DatasetHandle, ModelHandle, NotebookHandle, ResourceHandle
#       8 DATASETS_CACHE_SUBFOLDER = "datasets"
#       9 NOTEBOOKS_CACHE_SUBFOLDER = "notebooks"  # for resources under kaggle.com/code
#
# File /opt/conda/lib/python3.11/site-packages/kagglehub/handle.py:6
#       3 import abc
#       4 from dataclasses import asdict, dataclass
# ----> 6 from kagglesdk.kaggle_env import get_env, get_web_endpoint
#       7 from kagglesdk.models.types.model_enums import ModelFramework
#       9 from kagglehub.enum import to_enum
#
# ImportError: cannot import name 'get_web_endpoint' from 'kagglesdk.kaggle_env' (/opt/conda/lib/python3.11/site-packages/kagglesdk/kaggle_env.py)
